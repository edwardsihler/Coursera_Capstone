# %% [markdown]
# Welcome to my Capstone project notebook for IBM Applied Data Science Capstone project

# %%
import pandas as pd
import numpy as np
print ('Hello Capstone Project Course')
# Out:
# Hello Capstone Project Course

# %%
np.version
# Out:
# <module 'numpy.version' from '/srv/conda/envs/notebook/lib/python3.6/site-packages/numpy/version.py'>

# %%
pd.show_versions(as_json=False)
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : None
# python           : 3.6.10.final.0
# python-bits      : 64
# OS               : Linux
# OS-release       : 4.15.0-101-generic
# machine          : x86_64
# processor        : x86_64
# byteorder        : little
# LC_ALL           : en_US.UTF-8
# LANG             : en_US.UTF-8
# LOCALE           : en_US.UTF-8
#
# pandas           : 1.0.4
# numpy            : 1.18.5
# pytz             : 2020.1
# dateutil         : 2.8.1
# pip              : 20.1.1
# setuptools       : 47.1.1.post20200529
# Cython           : 0.29.19
# pytest           : None
# hypothesis       : None
# sphinx           : None
# blosc            : None
# feather          : None
# xlsxwriter       : None
# lxml.etree       : None
# html5lib         : None
# pymysql          : None
# psycopg2         : None
# jinja2           : 2.11.2
# IPython          : 7.15.0
# pandas_datareader: None
# bs4              : None
# bottleneck       : None
# ...
